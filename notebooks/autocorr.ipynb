# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
import datetime
import tqdm

# %%
def autocross(x, y):
    c = scipy.signal.correlate(x, y, mode="same")
    v = np.array([c[i]/( len(x)-abs( i - (len(x)/2)  ) ) for i in range(len(c))])
    return v

# %%
def autocorr5(x):
    mean=x.mean()
    var=numpy.var(x)
    xp=x-mean
    corr=scipy.signal.correlate(xp,xp,mode='full')[len(x)-1:]/var/len(x)
    return np.array(corr)

# %%
df = pd.read_csv('../database/clean_train_data_v4.csv', index_col = 0)

# %%
df.head()
# Out:
#          LATITUDE  LONGITUDE  ELEVATION  HourlyAltimeterSetting  \
# 118582  27.155831  77.960892     167.94               29.700939
# 755013  27.155831  77.960892     167.94               29.700939
# 824694  27.155831  77.960892     167.94               29.700939
# 830375  27.155831  77.960892     167.94               29.700939
# 680093  27.155831  77.960892     167.94               29.700939
#
#         HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# 118582                       61.0                      81.0
# 755013                       61.0                      81.0
# 824694                       61.0                      81.0
# 830375                       61.0                      81.0
# 680093                       61.0                      81.0
#
#         HourlyPresentWeatherType  HourlyPressureTendency  \
# 118582                         8                     9.0
# 755013                         8                     9.0
# ...

# %%
df.drop(columns=['HourlySkyConditions']).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 934807 entries, 118582 to 893344
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   LATITUDE                   934807 non-null  float64
#  1   LONGITUDE                  934807 non-null  float64
#  2   ELEVATION                  934807 non-null  float64
#  3   HourlyAltimeterSetting     934807 non-null  float64
#  4   HourlyDewPointTemperature  934807 non-null  float64
#  5   HourlyDryBulbTemperature   934807 non-null  float64
#  6   HourlyPresentWeatherType   934807 non-null  int64
#  7   HourlyPressureTendency     934807 non-null  float64
#  8   HourlyRelativeHumidity     934807 non-null  float64
#  9   HourlySeaLevelPressure     934807 non-null  float64
#  10  HourlyStationPressure      934807 non-null  float64
#  11  HourlyWetBulbTemperature   934807 non-null  float64
# ...

# %%
df.head()
# Out:
#          LATITUDE  LONGITUDE  ELEVATION  HourlyAltimeterSetting  \
# 118582  27.155831  77.960892     167.94               29.700939
# 755013  27.155831  77.960892     167.94               29.700939
# 824694  27.155831  77.960892     167.94               29.700939
# 830375  27.155831  77.960892     167.94               29.700939
# 680093  27.155831  77.960892     167.94               29.700939
#
#         HourlyDewPointTemperature  HourlyDryBulbTemperature  \
# 118582                       61.0                      81.0
# 755013                       61.0                      81.0
# 824694                       61.0                      81.0
# 830375                       61.0                      81.0
# 680093                       61.0                      81.0
#
#         HourlyPresentWeatherType  HourlyPressureTendency  \
# 118582                         8                     9.0
# 755013                         8                     9.0
# ...

# %%
location = []
for idx in tqdm.tqdm(range(len(df))):
    location.append(tuple([df.LATITUDE[idx], df.LONGITUDE[idx]]))

df['Location'] = pd.Series(location)
# Out:
# 100%|██████████| 934807/934807 [00:38<00:00, 24233.93it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 934807 entries, 118582 to 893344
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   LATITUDE                   934807 non-null  float64
#  1   LONGITUDE                  934807 non-null  float64
#  2   ELEVATION                  934807 non-null  float64
#  3   HourlyAltimeterSetting     934807 non-null  float64
#  4   HourlyDewPointTemperature  934807 non-null  float64
#  5   HourlyDryBulbTemperature   934807 non-null  float64
#  6   HourlyPresentWeatherType   934807 non-null  int64
#  7   HourlyPressureTendency     934807 non-null  float64
#  8   HourlyRelativeHumidity     934807 non-null  float64
#  9   HourlySeaLevelPressure     934807 non-null  float64
#  10  HourlyStationPressure      934807 non-null  float64
#  11  HourlyWetBulbTemperature   934807 non-null  float64
# ...

# %%
df.Location.value_counts()
# Out:
# (26.760594, 80.889339)              315313
# (23.287828, 69.670147)              119271
# (26.739708, 83.449708)              101532
# (25.160219, 75.84563100000001)      100011
# (27.155831, 77.960892)               86740
# (28.0, 73.3)                         50678
# (25.2333333, 86.95)                  36070
# (27.5666666, 81.6)                   21667
# (28.25, 74.9166666)                  16416
# (27.05, 88.2666666)                  14668
# (32.6666666, 74.83333329999999)      13673
# (25.0333333, 88.1333333)             13428
# (27.3333333, 88.6166666)              6697
# (27.6166666, 75.1333333)              6063
# (24.466666600000003, 74.9)            5456
# (27.8833333, 78.06666659999999)       4201
# (25.9833333, 79.5)                    3100
# (26.516666600000004, 93.9833333)      3079
# (27.0666666, 88.4666666)              3020
# (25.166666600000003, 93.0166666)      2979
# (23.3166666, 77.83333329999999)       2936
# (24.266666600000004, 87.25)           2781
# ...

# %%
df.drop(columns=['Location'], inplace=True)
